# %% [markdown]
# # Frequent Subtree Counting in Random Forests
#
# The goal of this project is to compress the generated source code of decision tree classifiers on embedded devices.
# Therefore, as a first step, we investigate for several trained random forests, whether they have certain frequent subtrees in common.
# Such subtrees might be implemented by a function which is called several times in the corresponding places of the decision trees.
# This can decrease the code size of the generated embedded-c source files and executables.
#
# ## Datasets
# There are several datasets.
# At the moment, however, I'll experiment only with 'adult' and 'wine-quality'.
# The data are given as json files of the following names:

# %%
ls forests/*/text/*.json
# Out:
# forests/adult/text/DT_10.json  forests/wine-quality/text/DT_10.json
# forests/adult/text/DT_15.json  forests/wine-quality/text/DT_15.json
# forests/adult/text/DT_1.json   forests/wine-quality/text/DT_1.json
# forests/adult/text/DT_20.json  forests/wine-quality/text/DT_20.json
# forests/adult/text/DT_5.json   forests/wine-quality/text/DT_5.json
# forests/adult/text/ET_10.json  forests/wine-quality/text/ET_10.json
# forests/adult/text/ET_15.json  forests/wine-quality/text/ET_15.json
# forests/adult/text/ET_1.json   forests/wine-quality/text/ET_1.json
# forests/adult/text/ET_20.json  forests/wine-quality/text/ET_20.json
# forests/adult/text/ET_5.json   forests/wine-quality/text/ET_5.json
# forests/adult/text/RF_10.json  forests/wine-quality/text/RF_10.json
# forests/adult/text/RF_15.json  forests/wine-quality/text/RF_15.json
# forests/adult/text/RF_1.json   forests/wine-quality/text/RF_1.json
# forests/adult/text/RF_20.json  forests/wine-quality/text/RF_20.json
# forests/adult/text/RF_5.json   forests/wine-quality/text/RF_5.json

# %% [markdown]
# The filenames XX_n.json mean:
# - XX:
#   - DT decision tree
#   - RF random forest with 25 trees
#   - ET 'extremely random trees'
# - n: depth of the trees
#
# Each tree given here (whether as a decision tree or as a component in a random forest) is a rooted, binary, ordered tree.
#
# ## Convert the Data
#
# We have written a few scripts to convert from json to the format required by the frequent subgraph mining software.

# %%
ls ./*.py
# Out:
# ./json2graphNoLeafEdges.py  ./json2graphWithLeafEdges.py

# %% [markdown]
# See the documentation of the scripts to check what they are doing:

# %%
for f in ./*.py; do
    echo ${f}
    grep '^#' < ${f}
    echo
done
# Out:
# ./json2graphNoLeafEdges.py
# ## This script creates a graph database from the decision trees in Sebastians json Format as follows:
# # - the root vertex of the tree has index 1 (counting starts with 1)
# # - each vertex is labeled by its split feature or by 'leaf'
# # - each edge is labeled either 'leftChild' or 'rightChild'
# # - there are no edges containing 'leaf' vertices
# #
# # It follows that the connected components resulting from a single decision tree are several isolated vertices labeled 'leaf'
# # and a tree containing all the split vertices.
#
# ./json2graphWithLeafEdges.py
# ## This script creates a graph database from the decision trees in Sebastians json Format as follows:
# # - the root vertex of the tree has index 1 (counting starts with 1)
# # - each vertex is labeled by its split feature or by 'leaf'
# # - each edge is labeled either 'leftChild' or 'rightChild'
# # - for each edge in a decision tree there is an edge in the graph database
# #
# # It follows that the resulting trees in the database correspond 1-1 to the decision trees in the json.
# # However, we fiddle with the labels of the vertices and forget, e.g., the threshold on which to split.

# %%
mkdir forests/adult/WithLeafEdges/
mkdir forests/adult/NoLeafEdges/

mkdir forests/wine-quality/WithLeafEdges/
mkdir forests/wine-quality/NoLeafEdges/

# %%
for dataset in adult wine-quality; do
    for f in forests/${dataset}/text/*.json; do
        echo ${f} '->' `basename ${f} .json`.graph
        python json2graphWithLeafEdges.py ${f} > forests/${dataset}/WithLeafEdges/`basename ${f} .json`.graph
        python json2graphNoLeafEdges.py ${f} > forests/${dataset}/NoLeafEdges/`basename ${f} .json`.graph
    done
done
# Out:
# forests/adult/text/DT_10.json -> DT_10.graph
# forests/adult/text/DT_15.json -> DT_15.graph
# forests/adult/text/DT_1.json -> DT_1.graph
# forests/adult/text/DT_20.json -> DT_20.graph
# forests/adult/text/DT_5.json -> DT_5.graph
# forests/adult/text/ET_10.json -> ET_10.graph
# forests/adult/text/ET_15.json -> ET_15.graph
# forests/adult/text/ET_1.json -> ET_1.graph
# forests/adult/text/ET_20.json -> ET_20.graph
# forests/adult/text/ET_5.json -> ET_5.graph
# forests/adult/text/RF_10.json -> RF_10.graph
# forests/adult/text/RF_15.json -> RF_15.graph
# forests/adult/text/RF_1.json -> RF_1.graph
# forests/adult/text/RF_20.json -> RF_20.graph
# forests/adult/text/RF_5.json -> RF_5.graph
# forests/wine-quality/text/DT_10.json -> DT_10.graph
# forests/wine-quality/text/DT_15.json -> DT_15.graph
# forests/wine-quality/text/DT_1.json -> DT_1.graph
# forests/wine-quality/text/DT_20.json -> DT_20.graph
# forests/wine-quality/text/DT_5.json -> DT_5.graph
# forests/wine-quality/text/ET_10.json -> ET_10.graph
# forests/wine-quality/text/ET_15.json -> ET_15.graph
# forests/wine-quality/text/ET_1.json -> ET_1.graph
# forests/wine-quality/text/ET_20.json -> ET_20.graph
# forests/wine-quality/text/ET_5.json -> ET_5.graph
# forests/wine-quality/text/RF_10.json -> RF_10.graph
# forests/wine-quality/text/RF_15.json -> RF_15.graph
# forests/wine-quality/text/RF_1.json -> RF_1.graph
# forests/wine-quality/text/RF_20.json -> RF_20.graph
# forests/wine-quality/text/RF_5.json -> RF_5.graph

# %% [markdown]
# ## Find Frequent Subtrees
#
# To be able to meaningfully find frequent subtrees here, we actually need to do two things in the graph mining executable:
# - make the algorithm able to deal with rooted trees in a meaningful way
# - make the algorithm output at least the root vertex of an embedding (if it exists for a given transaction tree) instead of just 'there is a mapping'
#
# ### Find Frequent Undirected Trees
#
# Regardless of the above, I'll first check, how many undirected frequent trees we can find in the 'unrooted variant' of the random forests.
# That is: We consider the undirected graphs arising from the rooted decision trees by 'forgetting' the root.
# If there exists a subgraph isomorphism in the rooted variant, then this implies that there exists a subgraph isomorphism in this undirected version.
# Hence, the number of frequent undirected subtrees is an upper bound on the number of the frequent directed subtrees.

# %%
# create output directories
mkdir forests/undirectedFrequentTrees/
for dataset in adult wine-quality; do
    mkdir forests/undirectedFrequentTrees/${dataset}/
    for variant in WithLeafEdges NoLeafEdges; do
        mkdir forests/undirectedFrequentTrees/${dataset}/${variant}/
    done
done

# %%
./lwg -h
# Out:
# This is a frequent subtree mining tool.
# Implemented by Pascal Welke starting in 2016.
#
# This program computes and outputs frequent subtrees according to several
# definitions of that notion and feature representations of the mined graphs.
#
# usage: ./lwg [options] [FILE]
#
# If no FILE argument is given or FILE is - the program reads from stdin.
# It always prints to stdout (embedding info) and stderr (statistics).
#
#
# Options:
# -h:           print this possibly helpful information.
#
# -t THRESHOLD: Minimum absolute support threshold in the graph database
#
# -p SIZE:      Maximum size (number of vertices) of patterns returned
#
# -o FILE:      output the frequent subtrees in this file
#
# -i VALUE:     Some embedding operators require a parameter that might be
#               a float between 0.0 and 1.0 or an integer >=1, depending
#               on the operator.
#
# -r VALUE:     Initialize the random number generator with seed VALUE. If
#               not specified, random generator is seeded according to
#               current time.
#
#
# -m METHOD:    Choose mining method among
#
#               bfs: (default) mine in a levelwise fashion (like apriori).
#                  This results in better pruning behavior, but large memory
#                  footprint
#               dfs: mine in a depth-first fashion (like FP-growth). This
#                  results in better memory footprint, but larger run time.
#
#
# -e OPERATOR:  Select the algorithm to decide whether a tree pattern
#               matches a transaction graph.
#               Choose embedding operator among the following:
#
#          == EXACT TREE EMBEDDING OPERATORS ==
#            These operators result in the full set of frequent
#            subtrees being output by this mining algorithm.
#
#            subtree: (default) classical subtree isomorphism algorithm.
#              A pattern matches a graph, if it is subgraph isomorphic
#              to it. Works only for forest transaction databases.
#              The algorithm is described in
#              Shamir & Tsur: Faster Subtree Isomorphism.
#              Journal of Algorithms (33), 1999, pp. 267-280
#
#            iterative: classical subtree isomorphism algorithm in an
#              iterative version. Uses more space than subtree, but
#              might increase mining speed in some cases. Works only
#              for forest transaction databases.
#
#            localEasy: My implementation of the local easy subtree iso-
#              morphism algorithm. Works for arbitrary graph transaction
#              databases. However, has polynomial delay only for local
#              easy graph databases. The algorithm is described in
#              Welke, Horvath, Wrobel: Probabilistic and Exact Frequent
#              Subtree Mining in Graphs Beyond Forests. (Chapter 3)
#              Machine Learning (to appear).
#
#            exactGlobalTreeEnumeration: Frequent Subtree Features.
#              Works for 'not too complex' graph transaction databases.
#              That is, this algorithm enumerates all global spanning
#              trees of each graph and checks for subtree isomorphism
#              of a pattern in the complete spanning tree forest (using
#              the subtree method above).
#
#
#          == STRANGE EMBEDDING OPERATORS ==
#            These operators do various stuff. The first two are
#            stronger than subgraph isomorphism, requiring possibly
#            more than one embedding into a transaction graph to
#            match the graph. The third just enumerates all trees
#            up to isomorphism that can be created from the vertex
#            and edge labels in the database.
#
#            absImp: absolute importance threshold (specify using -i).
#              A pattern needs to be subtree of at least i connected
#              components of a graph to match the graph. Works only
#              for forest transaction databases.
#
#            relImp: relative importance threshold (specify using -i).
#              A pattern needs to be subtree of at least a -i fraction
#              of connected components of a graph to match it. Works
#              only for forest transaction databases.
#
#            treeEnumeration: Enumerate all trees up to isomorphism which
#              can be generated from frequent vertices and edges in the
#              input databases.
#
#
#          == INCOMPLETE EMBEDDING OPERATORS ==
#            The embedding operators in this section result in an
#            incomplete enumeration of the set of frequent subtrees
#            in a graph database. The pattern set returned by the mining
#            algorithm using one of these operators is always a subset of
#            the set of all frequent subtrees of the graph database.
#            These algorithms are randomized and depend on the -r
#            parameter for random seeding. The -i parameter influences
#            the sampling rate and hence the runtime and the accuracy.
#            The resulting mining algorithm guarantees incremental
#            polynomial delay.
#
#            probabilisticTreeSampling: Probabilistic Subtree Features.
#              Works for arbitrary graph transaction databases with
#              polynomial delay. The -i parameter specifies the number of
#              spanning trees that are sampled for each graph in the
#              database. The spt-sampling takes place only once for each
#              transaction graph at the beginning of the mining.
#              The resulting mining algorithm is described in
#              Welke, Horvath, Wrobel: Probabilistic Frequent Subtrees
#              for Efficient Graph Classification and Retrieval. (Chapter 3)
#              Machine Learning (107), 2018, pp. 1847-1873
#
#            probabilisticTreeSamplingFK: Probabilistic Subtree Features,
#              based on a simplified algorithm, motivated by the ideas of
#              Fürer & Kasiviswanathan: Approximately Counting Embeddings
#              into Random Graphs.
#              Combinatorics, Probability & Computing (23), 2014,
#              pp.1028-1056.         The algorithm just tries to embed
#              the pattern tree somewhere in the graph using a combined
#              dfs/bfs strategy. Once a pattern vertex is mapped to a
#              transaction vertex, it will not change. Hence, the algorithm
#              finds in O(V(H)) whether a particular embedding works.
#              The maximum number of such trials for each (pattern tree,
#              transaction graph) tuple can be set by the -i parameter,
#              which has to be an integer. For each invocation, new random
#              choices are made. This means that this embedding operator
#              destroys the apriori property.
#
#            probabilisticTreeSamplingFKR: Probabilistic Subtree Features,
#              as above; difference is that there is more randomness in the
#              matching algorithm, as the neighbors of the pattern vertex
#              and the neighbors of its image are shuffled before the alg.
#              tries to assign the neighbors. The above version only shuffles
#              the neighbors of the pattern vertex, which might be not
#              sufficient, as there is often only one such neighbor.
#
#            localEasySampling: Boosted Probabilistic Subtree Features.
#              My implementation of the local easy tree sampling algorithm.
#              The -i parameter specifies the number of local spanning trees
#              that are sampled for each set of v-rooted components. The spt-
#              sampling takes place only once for each transaction graph at
#              the beginning of the mining. The algorithm is described in
#              Welke, Horvath, Wrobel: Probabilistic and Exact Frequent
#              Subtree Mining in Graphs Beyond Forests. (Chapter 4)
#              Machine Learning (to appear).
#
#            localEasyResampling: Boosted Probabilistic Subtree Features.
#              Difference to the above embedding operator: For each
#              evaluation of the embedding operator, a (possibly) novel
#              sample of local spanning trees is drawn. This destroys the
#              apriori-property of the embedding operator.
#
#            localEasySamplingSlow:
#
#            localEasySamplingIndependent:

# %%
for dataset in adult wine-quality; do
    for variant in WithLeafEdges NoLeafEdges; do
        for f in forests/${dataset}/${variant}/*.graph; do
            for threshold in `seq 25 -1 2`; do
            
                echo "processing threshold ${threshold} for ${f}"
                ./lwg -e subtree -m bfs -t ${threshold} -p 10 \
                  -o forests/undirectedFrequentTrees/${dataset}/${variant}/`basename ${f} .graph`_t${threshold}.patterns \
                  < ${f} \
                  > forests/undirectedFrequentTrees/${dataset}/${variant}/`basename ${f} .graph`_t${threshold}.features \
                  2> forests/undirectedFrequentTrees/${dataset}/${variant}/`basename ${f} .graph`_t${threshold}.logs
                  
            done
        done
    done
done
# Out:
# processing threshold 25 for forests/adult/WithLeafEdges/DT_10.graph
# processing threshold
for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 14 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 13 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 12 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 11 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 10 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 9 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 8 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 7 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 6 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 5 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 4 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 3 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 2 for forests/adult/NoLeafEdges/ET_1.graph
# processing threshold 25 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 24 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 23 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 22 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 21 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 20 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 19 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 18 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 17 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 16 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 15 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 14 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 13 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 12 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 11 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 10 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 9 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 8 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 7 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 6 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 5 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 4 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 3 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 2 for forests/adult/NoLeafEdges/ET_20.graph
# processing threshold 25 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 24 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 23 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 22 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 21 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 20 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 19 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 18 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 17 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 16 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 15 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 14 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 13 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 12 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 11 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 10 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 9 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 8 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 7 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 6 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 5 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 4 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 3 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 2 for forests/adult/NoLeafEdges/ET_5.graph
# processing threshold 25 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 24 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 23 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 22 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 21 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 20 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 19 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 18 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 17 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 16 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 15 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 14 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 13 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 12 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 11 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 10 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 9 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 8 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 7 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 6 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 5 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 4 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 3 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 2 for forests/adult/NoLeafEdges/RF_10.graph
# processing threshold 25 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 24 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 23 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 22 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 21 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 20 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 19 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 18 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 17 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 16 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 15 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 14 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 13 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 12 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 11 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 10 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 9 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 8 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 7 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 6 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 5 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 4 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 3 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 2 for forests/adult/NoLeafEdges/RF_15.graph
# processing threshold 25 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 24 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 23 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 22 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 21 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 20 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 19 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 18 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 17 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 16 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 15 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 14 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 13 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 12 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 11 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 10 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 9 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 8 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 7 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 6 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 5 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 4 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 3 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 2 for forests/adult/NoLeafEdges/RF_1.graph
# processing threshold 25 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 24 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 23 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 22 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 21 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 20 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 19 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 18 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 17 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 16 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 15 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 14 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 13 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 12 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 11 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 10 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 9 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 8 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 7 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 6 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 5 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 4 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 3 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 2 for forests/adult/NoLeafEdges/RF_20.graph
# processing threshold 25 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 24 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 23 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 22 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 21 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 20 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 19 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 18 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 17 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 16 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 15 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 14 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 13 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 12 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 11 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 10 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 9 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 8 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 7 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 6 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 5 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 4 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 3 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 2 for forests/adult/NoLeafEdges/RF_5.graph
# processing threshold 25 for forests/wine-quality/WithLeafEdges/DT_10.graph
# processing threshold 24 for forests/wine-quality/WithLeafEdges/DT_10.graph
# processing threshold 23 for forests/wine-quality/WithLeafEdges/DT_10.graph
# ...
# processing threshold 6 for forests/wine-quality/NoLeafEdges/ET_10.graph
# processing threshold 5 for forests/wine-quality/NoLeafEdges/ET_10.graph
# processing threshold 4 for forests/wine-quality/NoLeafEdges/ET_10.graph
# processing threshold 3 for forests/wine-quality/NoLeafEdges/ET_10.graph
# processing threshold 2 for forests/wine-quality/NoLeafEdges/ET_10.graph
# processing threshold 25 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 24 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 23 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 22 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 21 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 20 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 19 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 18 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 17 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 16 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 15 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 14 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 13 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 12 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 11 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 10 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 9 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 8 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 7 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 6 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 5 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 4 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 3 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 2 for forests/wine-quality/NoLeafEdges/ET_15.graph
# processing threshold 25 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 24 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 23 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 22 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 21 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 20 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 19 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 18 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 17 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 16 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 15 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 14 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 13 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 12 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 11 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 10 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 9 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 8 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 7 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 6 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 5 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 4 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 3 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 2 for forests/wine-quality/NoLeafEdges/ET_1.graph
# processing threshold 25 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 24 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 23 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 22 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 21 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 20 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 19 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 18 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 17 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 16 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 15 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 14 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 13 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 12 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 11 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 10 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 9 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 8 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 7 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 6 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 5 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 4 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 3 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 2 for forests/wine-quality/NoLeafEdges/ET_20.graph
# processing threshold 25 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 24 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 23 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 22 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 21 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 20 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 19 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 18 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 17 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 16 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 15 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 14 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 13 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 12 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 11 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 10 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 9 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 8 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 7 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 6 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 5 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 4 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 3 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 2 for forests/wine-quality/NoLeafEdges/ET_5.graph
# processing threshold 25 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 24 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 23 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 22 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 21 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 20 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 19 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 18 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 17 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 16 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 15 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 14 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 13 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 12 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 11 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 10 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 9 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 8 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 7 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 6 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 5 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 4 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 3 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 2 for forests/wine-quality/NoLeafEdges/RF_10.graph
# processing threshold 25 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 24 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 23 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 22 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 21 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 20 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 19 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 18 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 17 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 16 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 15 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 14 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 13 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 12 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 11 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 10 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 9 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 8 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 7 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 6 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 5 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 4 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 3 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 2 for forests/wine-quality/NoLeafEdges/RF_15.graph
# processing threshold 25 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 24 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 23 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 22 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 21 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 20 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 19 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 18 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 17 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 16 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 15 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 14 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 13 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 12 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 11 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 10 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 9 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 8 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 7 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 6 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 5 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 4 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 3 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 2 for forests/wine-quality/NoLeafEdges/RF_1.graph
# processing threshold 25 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 24 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 23 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 22 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 21 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 20 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 19 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 18 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 17 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 16 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 15 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 14 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 13 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 12 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 11 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 10 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 9 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 8 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 7 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 6 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 5 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 4 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 3 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 2 for forests/wine-quality/NoLeafEdges/RF_20.graph
# processing threshold 25 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 24 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 23 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 22 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 21 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 20 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 19 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 18 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 17 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 16 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 15 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 14 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 13 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 12 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 11 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 10 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 9 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 8 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 7 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 6 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 5 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 4 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 3 for forests/wine-quality/NoLeafEdges/RF_5.graph
# processing threshold 2 for forests/wine-quality/NoLeafEdges/RF_5.graph

# %% [markdown]
# ### Next Steps
#
# The results of this mining process are plotted in the python3 notebook 'Plotting Results for Undirected Graphs.ipynb'.
# Note that the mining process resulting in output 'forests/undirectedFrequentTrees/adult/WithLeafEdges/ER_20_t2.*' did not finish properly and probably got killed due to excessive memory usage while processing patterns of size 6.
