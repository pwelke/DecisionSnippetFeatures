# %% [markdown]
# We have now computed, for all random forests and all frequency thresholds,
#
# - the frequent patterns ( Initial Rooted Frequent Subtree Mining (without embedding computation).ipynb )
# - all embeddings for each frequent pattern up to size 6 ( Find All Occurrences of All Frequent Patterns of Size up to 6.ipynb )
#
# Thus, we have lots of files that store the random forests and some embedding information of the patterns and files that contain pattern info.
#
# By loading a pair of files, e.g.,
#
#     forests/rootedFrequentTrees/adult/WithLeafEdges/leq6/ET_10_t16_allEmbeddings.json
#     forests/rootedFrequentTrees/adult/WithLeafEdges/leq6/ET_10_t16.json
#
# We have all the information necessary to see how much it helps us to replace all subtrees in a RF corresponding to a pattern with a function.

# %%
import json
from collections import Counter


def embeddingStatsRec(transaction, weightfunction, counter):
    if 'feature' in transaction.keys():
        if 'leftChild' in transaction.keys():
            embeddingStatsRec(transaction['leftChild'], weightfunction, counter)
        if 'rightChild' in transaction.keys():
            embeddingStatsRec(transaction['rightChild'], weightfunction, counter)
    
    for pattern in transaction['patterns']:
        counter[pattern[0]] += weightfunction(pattern, transaction)

    

def embeddingStats(transactions, weightfunction):
    '''Apply weightfunction to all embeddings of each pattern in each transaction and return, for each pattern,
    the sum of gains.
    
    Due to implementation, weightfunction must 
    - take a pattern and a transaction vertex (the root of the embedding being currently weighted) as input and 
    - output an int.
    '''
    cnt = Counter()
    for transaction in transactions:
        embeddingStatsRec(transaction, weightfunction, cnt)
    return cnt

# %%
# load some patterns and a random forest with all their embeddings

embeddingFile = open('/home/pascal/Documents/Uni_synced/random_forests/forests/rootedFrequentTrees/adult/WithLeafEdges/leq6/ET_10_t16_allEmbeddings.json')
patternFile = open('/home/pascal/Documents/Uni_synced/random_forests/forests/rootedFrequentTrees/adult/WithLeafEdges/leq6/ET_10_t16.json')

embeddingInfo = json.load(embeddingFile)
patterns = json.load(patternFile)

embeddingFile.close()
patternFile.close()

# %%
# transform the list of patterns to a dict for easy access

patternDict = { pattern['patternid'] : pattern['pattern'] for pattern in patterns}

# %%
# find the patterns that occur in at least 16 of the trees in ET_10 with most embeddings in ET_10
# that is, each embedding counts for 1

embeddingCounts = embeddingStats(embeddingInfo, weightfunction=lambda p,t : 1)
embeddingCounts.most_common(10)
# Out:
# [(10, 8177),
#  (3, 566),
#  (1, 548),
#  (52, 521),
#  (22, 508),
#  (155, 489),
#  (75, 373),
#  (6, 350),
#  (157, 339),
#  (156, 332)]

# %%
# we can access the corresponding patterns like this

patternDict[10]
# Out:
# {'id': 0, 'prediction': []}

# %% [markdown]
# As we can see, (and as was to be expected) the pattern that occurs most frequently is rather small.
# I.e., it consists of a single vertex.
#
# This of course is not a useful pattern to be replaced by a function call.
#
# Let's try a different weight function, that tells us, how much vertices we could save in the RF by contracting each embedding of a pattern into a single vertex:

# %%
embeddingSavings = embeddingStats(embeddingInfo, weightfunction=lambda p,t : 1 if len(p[1]) - 1 > 1 else 0)
embeddingSavings.most_common(10)
# Out:
# [(193, 276),
#  (160, 266),
#  (174, 225),
#  (161, 217),
#  (162, 117),
#  (168, 91),
#  (180, 87),
#  (167, 78),
#  (171, 76),
#  (169, 73)]

# %%
list(map(lambda x: '{0}: w={1}, p={2}'.format(x[0], x[1], patternDict[x[0]]), embeddingSavings.most_common(10)))
# Out:
# ["193: w=276, p={'id': 0, 'feature': 9, 'leftChild': {'id': 1, 'prediction': []}, 'rightChild': {'id': 2, 'prediction': []}}",
#  "160: w=266, p={'id': 0, 'feature': 0, 'leftChild': {'id': 1, 'prediction': []}, 'rightChild': {'id': 2, 'prediction': []}}",
#  "174: w=225, p={'id': 0, 'feature': 63, 'leftChild': {'id': 1, 'prediction': []}, 'rightChild': {'id': 2, 'prediction': []}}",
#  "161: w=217, p={'id': 0, 'feature': 61, 'leftChild': {'id': 1, 'prediction': []}, 'rightChild': {'id': 2, 'prediction': []}}",
#  "162: w=117, p={'id': 0, 'feature': 62, 'leftChild': {'id': 1, 'prediction': []}, 'rightChild': {'id': 2, 'prediction': []}}",
#  "168: w=91, p={'id': 0, 'feature': 54, 'leftChild': {'id': 1, 'prediction': []}, 'rightChild': {'id': 2, 'prediction': []}}",
#  "180: w=87, p={'id': 0, 'feature': 58, 'leftChild': {'id': 1, 'prediction': []}, 'rightChild': {'id': 2, 'prediction': []}}",
#  "167: w=78, p={'id': 0, 'feature': 1, 'leftChild': {'id': 1, 'prediction': []}, 'rightChild': {'id': 2, 'prediction': []}}",
#  "171: w=76, p={'id': 0, 'feature': 26, 'leftChild': {'id': 1, 'prediction': []}, 'rightChild': {'id': 2, 'prediction': []}}",
#  "169: w=73, p={'id': 0, 'feature': 2, 'leftChild': {'id': 1, 'prediction': []}, 'rightChild': {'id': 2, 'prediction': []}}"]

# %%
patternDict[193]
# Out:
# {'feature': 9,
#  'id': 0,
#  'leftChild': {'id': 1, 'prediction': []},
#  'rightChild': {'id': 2, 'prediction': []}}

# %% [markdown]
# ## Questions:
#
# - What are useful weighting functions for our actual scenario?
# - How do we deal with overlaps of the embeddings?
#   - Is it more useful to process patterns that are higher up in the DT first? (I guess)

# %%
f = open('forests/adult/text/DT_5.json')
dt5 = json.load(f)
f.close()

# %%
# return the number of samples that hit a pattern, if the pattern is larger than 1 vertex
def weightByNumSamples(pattern, transaction):
    if len(pattern[1]) > 1:
        return transaction['numSamples']
    else:
        return 0

# %%
print(json.dumps(dt5, indent=2))
# Out:
# [
#   {
#     "id": 0,
#     "numSamples": 15355,
#     "probLeft": 0.27359166395310974,
#     "probRight": 0.7264083360468903,
#     "isCategorical": "False",
#     "feature": 0,
#     "split": 28,
#     "leftChild": {
#       "id": 1,
#       "numSamples": 4201,
#       "probLeft": 0.9926208045703404,
#       "probRight": 0.007379195429659605,
#       "isCategorical": "False",
#       "feature": 61,
#       "split": 7073,
#       "leftChild": {
#         "id": 2,
#         "numSamples": 4170,
#         "probLeft": 0.8630695443645084,
#         "probRight": 0.1369304556354916,
#         "isCategorical": "False",
#         "feature": 50,
#         "split": 0,
#         "leftChild": {
#           "id": 3,
#           "numSamples": 3599,
#           "probLeft": 0.5193109196999166,
#           "probRight": 0.48068908030008334,
#           "isCategorical": "False",
#           "feature": 60,
#           "split": 0,
#           "leftChild": {
#             "id": 4,
#             "numSamples": 1869,
#             "probLeft": 0.7774210807918673,
#             "probRight": 0.2225789192081327,
#             "isCategorical": "False",
#             "feature": 0,
#             "split": 25,
#             "leftChild": {
#               "id": 5,
#               "numSamples": 1453,
#               "prediction": [
#                 0.9942806863176419,
#                 0.005719313682358117
#               ]
#             },
#             "rightChild": {
#               "id": 6,
#               "numSamples": 416,
#               "prediction": [
#                 0.9715994020926756,
#                 0.028400597907324365
#               ]
#             }
#           },
#           "rightChild": {
#             "id": 7,
#             "numSamples": 1730,
#             "probLeft": 0.7549132947976879,
#             "probRight": 0.24508670520231213,
#             "isCategorical": "False",
#             "feature": 9,
#             "split": 237272,
#             "leftChild": {
#               "id": 8,
#               "numSamples": 1306,
#               "prediction": [
#                 0.9818094782192437,
#                 0.018190521780756343
#               ]
#             },
#             "rightChild": {
#               "id": 9,
#               "numSamples": 424,
#               "prediction": [
#                 0.9636363636363636,
#                 0.03636363636363636
#               ]
#             }
#           }
#         },
#         "rightChild": {
#           "id": 10,
#           "numSamples": 571,
#           "probLeft": 0.6217162872154116,
#           "probRight": 0.37828371278458844,
#           "isCategorical": "False",
#           "feature": 13,
#           "split": 0,
#           "leftChild": {
#             "id": 11,
#             "numSamples": 355,
#             "probLeft": 0.9549295774647887,
#             "probRight": 0.04507042253521127,
#             "isCategorical": "False",
#             "feature": 34,
#             "split": 0,
#             "leftChild": {
#               "id": 12,
#               "numSamples": 339,
#               "prediction": [
#                 0.7859848484848485,
#                 0.21401515151515152
#               ]
#             },
#             "rightChild": {
#               "id": 13,
#               "numSamples": 16,
#               "prediction": [
#                 0.5769230769230769,
#                 0.4230769230769231
#               ]
#             }
#           },
#           "rightChild": {
#             "id": 14,
#             "numSamples": 216,
#             "probLeft": 0.9907407407407407,
#             "probRight": 0.009259259259259259,
#             "isCategorical": "False",
#             "feature": 63,
#             "split": 76,
#             "leftChild": {
#               "id": 15,
#               "numSamples": 214,
#               "prediction": [
#                 0.896875,
#                 0.103125
#               ]
#             },
#             "rightChild": {
#               "id": 16,
#               "numSamples": 2,
#               "prediction": [
#                 0.25,
#                 0.75
#               ]
#             }
#           }
#         }
#       },
#       "rightChild": {
#         "id": 17,
#         "numSamples": 31,
#         "probLeft": 0.7419354838709677,
#         "probRight": 0.25806451612903225,
#         "isCategorical": "False",
#         "feature": 11,
#         "split": 0,
#         "leftChild": {
#           "id": 18,
#           "numSamples": 23,
#           "probLeft": 0.8695652173913043,
#           "probRight": 0.13043478260869565,
#           "isCategorical": "False",
#           "feature": 61,
#           "split": 30961,
#           "leftChild": {
#             "id": 19,
#             "numSamples": 20,
#             "prediction": [
#               0.0,
#               1.0
#             ]
#           },
#           "rightChild": {
#             "id": 20,
#             "numSamples": 3,
#             "probLeft": 0.3333333333333333,
#             "probRight": 0.6666666666666666,
#             "isCategorical": "False",
#             "feature": 0,
#             "split": 20,
#             "leftChild": {
#               "id": 21,
#               "numSamples": 1,
#               "prediction": [
#                 1.0,
#                 0.0
#               ]
#             },
#             "rightChild": {
#               "id": 22,
#               "numSamples": 2,
#               "prediction": [
#                 0.0,
#                 1.0
#               ]
#             }
#           }
#         },
#         "rightChild": {
#           "id": 23,
#           "numSamples": 8,
#           "prediction": [
#             0.0,
#             1.0
#           ]
#         }
#       }
#     },
#     "rightChild": {
#       "id": 24,
#       "numSamples": 11154,
#       "probLeft": 0.49390353236507084,
#       "probRight": 0.5060964676349292,
#       "isCategorical": "False",
#       "feature": 50,
#       "split": 0,
#       "leftChild": {
#         "id": 25,
#         "numSamples": 5509,
#         "probLeft": 0.9676892357959702,
#         "probRight": 0.03231076420402977,
#         "isCategorical": "False",
#         "feature": 61,
#         "split": 7073,
#         "leftChild": {
#           "id": 26,
#           "numSamples": 5331,
#           "probLeft": 0.8493716000750329,
#           "probRight": 0.15062839992496718,
#           "isCategorical": "False",
#           "feature": 10,
#           "split": 0,
#           "leftChild": {
#             "id": 27,
#             "numSamples": 4528,
#             "probLeft": 0.6303003533568905,
#             "probRight": 0.36969964664310956,
#             "isCategorical": "False",
#             "feature": 28,
#             "split": 0,
#             "leftChild": {
#               "id": 28,
#               "numSamples": 2854,
#               "prediction": [
#                 0.8808791208791209,
#                 0.11912087912087913
#               ]
#             },
#             "rightChild": {
#               "id": 29,
#               "numSamples": 1674,
#               "prediction": [
#                 0.9359457422758101,
#                 0.0640542577241899
#               ]
#             }
#           },
#           "rightChild": {
#             "id": 30,
#             "numSamples": 803,
#             "probLeft": 0.5616438356164384,
#             "probRight": 0.4383561643835616,
#             "isCategorical": "False",
#             "feature": 29,
#             "split": 0,
#             "leftChild": {
#               "id": 31,
#               "numSamples": 451,
#               "prediction": [
#                 0.6621621621621622,
#                 0.33783783783783783
#               ]
#             },
#             "rightChild": {
#               "id": 32,
#               "numSamples": 352,
#               "prediction": [
#                 0.8410714285714286,
#                 0.15892857142857142
#               ]
#             }
#           }
#         },
#         "rightChild": {
#           "id": 33,
#           "numSamples": 178,
#           "probLeft": 0.8595505617977528,
#           "probRight": 0.1404494382022472,
#           "isCategorical": "False",
#           "feature": 42,
#           "split": 0,
#           "leftChild": {
#             "id": 34,
#             "numSamples": 153,
#             "probLeft": 0.9411764705882353,
#             "probRight": 0.058823529411764705,
#             "isCategorical": "False",
#             "feature": 0,
#             "split": 63,
#             "leftChild": {
#               "id": 35,
#               "numSamples": 144,
#               "prediction": [
#                 0.013636363636363636,
#                 0.9863636363636363
#               ]
#             },
#             "rightChild": {
#               "id": 36,
#               "numSamples": 9,
#               "prediction": [
#                 0.13333333333333333,
#                 0.8666666666666667
#               ]
#             }
#           },
#           "rightChild": {
#             "id": 37,
#             "numSamples": 25,
#             "probLeft": 0.96,
#             "probRight": 0.04,
#             "isCategorical": "False",
#             "feature": 30,
#             "split": 0,
#             "leftChild": {
#               "id": 38,
#               "numSamples": 24,
#               "prediction": [
#                 0.02702702702702703,
#                 0.972972972972973
#               ]
#             },
#             "rightChild": {
#               "id": 39,
#               "numSamples": 1,
#               "prediction": [
#                 1.0,
#                 0.0
#               ]
#             }
#           }
#         }
#       },
#       "rightChild": {
#         "id": 40,
#         "numSamples": 5645,
#         "probLeft": 0.9277236492471214,
#         "probRight": 0.07227635075287865,
#         "isCategorical": "False",
#         "feature": 20,
#         "split": 0,
#         "leftChild": {
#           "id": 41,
#           "numSamples": 5237,
#           "probLeft": 0.8420851632614093,
#           "probRight": 0.1579148367385908,
#           "isCategorical": "False",
#           "feature": 38,
#           "split": 0,
#           "leftChild": {
#             "id": 42,
#             "numSamples": 4410,
#             "probLeft": 0.9551020408163265,
#             "probRight": 0.044897959183673466,
#             "isCategorical": "False",
#             "feature": 3,
#             "split": 0,
#             "leftChild": {
#               "id": 43,
#               "numSamples": 4212,
#               "prediction": [
#                 0.5998209489704566,
#                 0.40017905102954343
#               ]
#             },
#             "rightChild": {
#               "id": 44,
#               "numSamples": 198,
#               "prediction": [
#                 0.3595166163141994,
#                 0.6404833836858006
#               ]
#             }
#           },
#           "rightChild": {
#             "id": 45,
#             "numSamples": 827,
#             "probLeft": 0.8657799274486094,
#             "probRight": 0.13422007255139057,
#             "isCategorical": "False",
#             "feature": 2,
#             "split": 0,
#             "leftChild": {
#               "id": 46,
#               "numSamples": 716,
#               "prediction": [
#                 0.3026086956521739,
#                 0.697391304347826
#               ]
#             },
#             "rightChild": {
#               "id": 47,
#               "numSamples": 111,
#               "prediction": [
#                 0.6505376344086021,
#                 0.34946236559139787
#               ]
#             }
#           }
#         },
#         "rightChild": {
#           "id": 48,
#           "numSamples": 408,
#           "probLeft": 0.9681372549019608,
#           "probRight": 0.031862745098039214,
#           "isCategorical": "False",
#           "feature": 42,
#           "split": 0,
#           "leftChild": {
#             "id": 49,
#             "numSamples": 395,
#             "probLeft": 0.9949367088607595,
#             "probRight": 0.005063291139240506,
#             "isCategorical": "False",
#             "feature": 36,
#             "split": 0,
#             "leftChild": {
#               "id": 50,
#               "numSamples": 393,
#               "prediction": [
#                 0.2,
#                 0.8
#               ]
#             },
#             "rightChild": {
#               "id": 51,
#               "numSamples": 2,
#               "prediction": [
#                 1.0,
#                 0.0
#               ]
#             }
#           },
#           "rightChild": {
#             "id": 52,
#             "numSamples": 13,
#             "probLeft": 0.9230769230769231,
#             "probRight": 0.07692307692307693,
#             "isCategorical": "False",
#             "feature": 5,
#             "split": 0,
#             "leftChild": {
#               "id": 53,
#               "numSamples": 12,
#               "prediction": [
#                 0.6363636363636364,
#                 0.36363636363636365
#               ]
#             },
#             "rightChild": {
#               "id": 54,
#               "numSamples": 1,
#               "prediction": [
#                 0.0,
#                 1.0
#               ]
#             }
#           }
#         }
#       }
#     }
#   }
# ]
