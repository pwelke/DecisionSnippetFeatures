# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

dataSet = 'adult'
scoring_function = 'accuracy'
scoring_function_Reg = 'neg_mean_squared_error'
resultsPath = "/home/falkhoury/Study/Lab/Project/frequentTreesInRandomForests/forests/rootedFrequentTrees/"
res_list_rf_5=[]
res_list_rf_10=[]
res_list_rf_15=[]
res_list_rf_20=[]
res_list_normal=[]
res_list_dt=[]
res_list_rf=[]
best=''
best_value=0
best_Reg=''
best_value_Reg=0
best_dt=''
best_value_dt=0
best_rf=''
best_value_rf=0

# %%
    #Classification
    res_list_dsf_rf_5=[]
    res_list_dsf_rf_10=[]
    res_list_dsf_rf_15=[]
    res_list_dsf_rf_20=[]
    res_list_normal=[]
    res_list_dt=[]
    res_list_dt_5=[]
    res_list_dt_10=[]
    res_list_dt_15=[]
    res_list_dt_20=[]
    res_list_rf=[]
    res_list_rf_5=[]
    res_list_rf_10=[]
    res_list_rf_15=[]
    res_list_rf_20=[]
    best=''
    best_value=0
    best_dt=''
    best_value_dt=0
    best_rf=''
    best_value_rf=0
    pattern_max_size = 6
    variant = 'WithLeafEdges'
    
  
    with open(resultsPath+dataSet+'/Results_'+variant+'/leq'+str(pattern_max_size)+'/'+'RF_'+str(5)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_5.append(rowStr[1])
                res_list_normal.append(rowStr[2])
                res_list_dt_5.append(rowStr[3])
                res_list_rf_5.append(rowStr[4])
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_5_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    res_list_rf_10=[]
    with open(resultsPath+dataSet+'/Results_'+variant+'/leq'+str(pattern_max_size)+'/RF_'+str(10)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_10.append(rowStr[1])
                res_list_dt_10.append(rowStr[3])
                res_list_rf_10.append(rowStr[4]) 
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_10_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    res_list_rf_15=[]
    with open(resultsPath+dataSet+'/Results_'+variant+'/leq'+str(pattern_max_size)+'/RF_'+str(15)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_15.append(rowStr[1])
                res_list_dt_15.append(rowStr[3])
                res_list_rf_15.append(rowStr[4]) 
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_15_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    res_list_rf_20=[]
    with open(resultsPath+dataSet+'/Results_'+variant+'/leq'+str(pattern_max_size)+'/RF_'+str(20)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_20.append(rowStr[1])
                res_list_dt_20.append(rowStr[3])
                res_list_rf_20.append(rowStr[4]) 
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_20_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    f= open(resultsPath+dataSet+'/Results_'+variant+'/leq'+str(pattern_max_size)+'/RF_all'+'_'+scoring_function+'.csv',"w")
    f.write('Frequency'+','+'DSF_RF_5'+','+'DSF_RF_10'+','+'DSF_RF_15'+','+'DSF_RF_20'+','+
                    ','+'Normal Features'+','+'DT Classifier_5'+','+'RF Classifier_5'+','+'DT Classifier_10'+','+'RF Classifier_10'+
            ','+'DT Classifier_15'+','+'RF Classifier_15'+','+'DT Classifier_20'+','+'RF Classifier_20' +'\n')
    for i in range(24):
            f.write('t'+str(i+2)+','+res_list_dsf_rf_5[i]+','+res_list_dsf_rf_10[i]+','+res_list_dsf_rf_15[i]+','+res_list_dsf_rf_20[i]+','+
                    res_list_normal[i]+','+res_list_dt_5[i]+','+res_list_rf_5[i]+res_list_dt_10[i]+','+res_list_rf_10[i]+
                    res_list_dt_15[i]+','+res_list_rf_15[i]+res_list_dt_20[i]+','+res_list_rf_20[i]+'\n')
    f.close()
    
    #DT
    if (float(res_list_dt_5[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_5[1])
        best_dt='DT_5'
        res_list_dt = res_list_dt_5
    if (float(res_list_dt_10[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_10[1])
        best_dt='DT_10'
        res_list_dt = res_list_dt_10
    if (float(res_list_dt_15[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_15[1])
        best_dt='DT_15'
        res_list_dt = res_list_dt_15
    if (float(res_list_dt_20[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_20[1])
        best_dt='DT_20'
        res_list_dt = res_list_dt_20
    #RF    
    if (float(res_list_rf_5[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_5[1])
        best_rf='RF_5'
        res_list_rf = res_list_rf_5
    if (float(res_list_rf_10[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_10[1])
        best_rf='RF_10'
        res_list_rf = res_list_rf_10
    if (float(res_list_rf_15[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_15[1])
        best_rf='RF_15'
        res_list_rf = res_list_rf_15
    if (float(res_list_rf_20[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_20[1])
        best_rf='RF_20'
        res_list_rf = res_list_rf_20

# %%
#Classification
x_axis=np.arange(2,26,1)
dsf_rf_5 = np.array(res_list_dsf_rf_5, dtype=np.float32)
dsf_rf_10 = np.array(res_list_dsf_rf_10, dtype=np.float32)
dsf_rf_15 = np.array(res_list_dsf_rf_15, dtype=np.float32)
dsf_rf_20 = np.array(res_list_dsf_rf_20, dtype=np.float32)
normal = np.array(res_list_normal, dtype=np.float32)
dt = np.array(res_list_dt, dtype=np.float32)
rf = np.array(res_list_rf, dtype=np.float32)

print('Best: '+best +': '+str(round(best_value,6)))
diff = normal[0] - best_value 
print('Difference from normal features: '+str(round(diff,6)))

diff_from_rf = best_value - best_value_rf

plt.plot(x_axis,dsf_rf_5)
plt.plot(x_axis,dsf_rf_10)
plt.plot(x_axis,dsf_rf_15)
plt.plot(x_axis,dsf_rf_20)
plt.plot(x_axis,normal)
plt.plot(x_axis,dt)
plt.plot(x_axis,rf)
plt.xlabel('Frequency')
plt.ylabel(scoring_function)

ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.60, box.height])
plt.legend(['DSF_RF_5', 'DSF_RF_10', 'DSF_RF_15', 'DSF_RF_20','normal features','DT Classifier','RF Classifier'],bbox_to_anchor=(1.0, 0.5), loc='upper left')
plt.text(27, 0.77, 'Best: '+best +': '+str(round(best_value,6))+'\n\n'+'Difference from normal \n features: '+str(round(diff,6))+'\n\n'+'Best RF: '+best_rf+ ' :'+str(round(best_value_rf,6))+
        '\n'+'Difference from RF Classifier: \n '+str(round(diff_from_rf,6))+'\n')
fig = plt.gcf()
fig.savefig(dataSet+'_'+variant+'_'+scoring_function+'.png', dpi=150)
fig.show()

# Notes 10 Dec meeting:

# display which RF depth is the best
# what we gain if the RF classifier is better than the frequent subtrees ?
# when the max depth is 5, we pruned 25 trees of the random forest
# check the computation time, RF is better than the frequent sebtrees.
# define the final goal clearly.
# Out:
# Best: RF_5_t14: 0.837167
# Difference from normal features: -0.042013
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:27: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
    #Regression
    res_list_dsf_rf_5=[]
    res_list_dsf_rf_10=[]
    res_list_dsf_rf_15=[]
    res_list_dsf_rf_20=[]
    res_list_normal=[]
    res_list_dt=[]
    res_list_dt_5=[]
    res_list_dt_10=[]
    res_list_dt_15=[]
    res_list_dt_20=[]
    res_list_rf=[]
    res_list_rf_5=[]
    res_list_rf_10=[]
    res_list_rf_15=[]
    res_list_rf_20=[]
    best=''
    best_value=-10
    best_Reg=''
    best_value_Reg=0
    best_dt=''
    best_value_dt=0
    best_rf=''
    best_value_rf=0
    pattern_max_size = 6
    
  
    with open(resultsPath+dataSet+'/leq'+str(pattern_max_size)+'/'+'RF_'+str(5)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_5.append(rowStr[1])
                res_list_normal.append(rowStr[2])
                res_list_dt_5.append(rowStr[3])
                res_list_rf_5.append(rowStr[4])               
                line_count+=1
    csv_file.close()
    
    res_list_rf_10=[]
    with open(resultsPath+dataSet+'/leq'+str(pattern_max_size)+'/RF_'+str(10)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_10.append(rowStr[1])
                res_list_dt_10.append(rowStr[3])
                res_list_rf_10.append(rowStr[4]) 
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_10_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    res_list_rf_15=[]
    with open(resultsPath+dataSet+'/leq'+str(pattern_max_size)+'/RF_'+str(15)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_15.append(rowStr[1])
                res_list_dt_15.append(rowStr[3])
                res_list_rf_15.append(rowStr[4]) 
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_15_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    res_list_rf_20=[]
    with open(resultsPath+dataSet+'/leq'+str(pattern_max_size)+'/RF_'+str(20)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_20.append(rowStr[1])
                res_list_dt_20.append(rowStr[3])
                res_list_rf_20.append(rowStr[4]) 
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_20_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    f= open(resultsPath+dataSet+'/leq'+str(pattern_max_size)+'/RF_all'+'_'+scoring_function+'.csv',"w")
    f.write('Frequency'+','+'DSF_RF_5'+','+'DSF_RF_10'+','+'DSF_RF_15'+','+'DSF_RF_20'+','+
                    ','+'Normal Features'+','+'DT Classifier_5'+','+'RF Classifier_5'+','+'DT Classifier_10'+','+'RF Classifier_10'+
            ','+'DT Classifier_15'+','+'RF Classifier_15'+','+'DT Classifier_20'+','+'RF Classifier_20' +'\n')
    for i in range(24):
            f.write('t'+str(i+2)+','+res_list_dsf_rf_5[i]+','+res_list_dsf_rf_10[i]+','+res_list_dsf_rf_15[i]+','+res_list_dsf_rf_20[i]+','+
                    res_list_normal[i]+','+res_list_dt_5[i]+','+res_list_rf_5[i]+res_list_dt_10[i]+','+res_list_rf_10[i]+
                    res_list_dt_15[i]+','+res_list_rf_15[i]+res_list_dt_20[i]+','+res_list_rf_20[i]+'\n')
    f.close()
    
    #DT
    if (float(res_list_dt_5[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_5[1])
        best_dt='DT_5'
        res_list_dt = res_list_dt_5
    if (float(res_list_dt_10[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_10[1])
        best_dt='DT_10'
        res_list_dt = res_list_dt_10
    if (float(res_list_dt_15[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_15[1])
        best_dt='DT_15'
        res_list_dt = res_list_dt_15
    if (float(res_list_dt_20[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_20[1])
        best_dt='DT_20'
        res_list_dt = res_list_dt_20
    #RF    
    if (float(res_list_rf_5[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_5[1])
        best_rf='RF_5'
        res_list_rf = res_list_rf_5
    if (float(res_list_rf_10[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_10[1])
        best_rf='RF_10'
        res_list_rf = res_list_rf_10
    if (float(res_list_rf_15[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_15[1])
        best_rf='RF_15'
        res_list_rf = res_list_rf_15
    if (float(res_list_rf_20[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_20[1])
        best_rf='RF_20'
        res_list_rf = res_list_rf_20

# %%
#Regression
x_axis=np.arange(2,26,1)




dsf_rf_5 = np.array(res_list_dsf_rf_5, dtype=np.float32)

dsf_rf_10 = np.array(res_list_dsf_rf_10, dtype=np.float32)
dsf_rf_15 = np.array(res_list_dsf_rf_15, dtype=np.float32)
dsf_rf_20 = np.array(res_list_dsf_rf_20, dtype=np.float32)
normal = np.array(res_list_normal, dtype=np.float32)
dt = np.array(res_list_dt, dtype=np.float32)
rf = np.array(res_list_rf, dtype=np.float32)

for i in range(0,24):
    if(dsf_rf_5[i] < -10):
        dsf_rf_5[i]=-1
    if(dsf_rf_10[i] < -10):
        dsf_rf_10[i]=-1
    if(dsf_rf_15[i] < -10):
        dsf_rf_15[i]=-1    
    if(dsf_rf_20[i] < -10):
        dsf_rf_20[i]=-1
        
        
print(dsf_rf_10)
print('Best: '+best +': '+str(round(best_value,6)))
diff = normal[0] - best_value 
print('Difference from normal features: '+str(round(diff,6)))

plt.plot(x_axis,dsf_rf_5)
plt.plot(x_axis,dsf_rf_10)
plt.plot(x_axis,dsf_rf_15)
plt.plot(x_axis,dsf_rf_20)
plt.plot(x_axis,normal)
#plt.plot(x_axis,dt)
#plt.plot(x_axis,rf)
plt.xlabel('Frequency')
plt.ylabel(scoring_function_Reg)

ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.75, box.height])
plt.legend(['DFS_RF_5', 'DFS_RF_10', 'DFS_RF_15', 'DFS_RF_20','normal features'],bbox_to_anchor=(1.0, 0.5), loc='upper left')
plt.text(27, -0.7, 'Best: '+best +': '+str(round(best_value,6))+'\n'+'Difference from normal \n features: '+str(round(diff,6)))
fig = plt.gcf()
fig.savefig(dataSet+'_'+scoring_function_Reg+'.png', dpi=150)
fig.show()
# Out:
# [-1.         -1.         -1.         -0.62370014 -0.6142953  -0.606398
#  -0.6097913  -0.6041078  -0.59664667 -0.60580736 -0.6254171  -0.60369116
#  -0.6070275  -0.61458457 -0.6354247  -0.75191206 -0.7812113  -0.76815605
#  -0.76815605 -0.76815605 -0.76815605 -0.76815605 -0.76815605 -0.76815605]
# Best: RF_15_t3: -0.584984
# Difference from normal features: 0.010067
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:42: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
    #Pattern size
 
    
    res_list_dsf_rf_10_leq2=[]
    res_list_dsf_rf_10_leq3=[]
    res_list_dsf_rf_10_leq4=[]
    res_list_dsf_rf_10_leq5=[]
    res_list_dsf_rf_10_leq6=[]
    res_list_dsf_rf_10_leq7=[]
    
    res_list_normal=[]
    res_list_dt=[]
    
    res_list_dt_10=[]
    
    res_list_rf=[]
    
    res_list_rf_10=[]
    
    best=''
    best_value=0
    best_dt=''
    best_value_dt=0
    best_rf=''
    best_value_rf=0
    pattern_max_size = 6
    
  
    with open(resultsPath+dataSet+'/leq'+str(2)+'/'+'RF_'+str(10)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_10_leq2.append(rowStr[1])
                res_list_normal.append(rowStr[2])
                res_list_dt_10.append(rowStr[3])
                res_list_rf_10.append(rowStr[4])
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_10_t'+str(line_count)+'_leq2'
                line_count+=1
    csv_file.close()
    
    with open(resultsPath+dataSet+'/leq'+str(3)+'/'+'RF_'+str(10)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_10_leq3.append(rowStr[1])
                
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_10_t'+str(line_count)+'_leq3'
                line_count+=1
    csv_file.close()
    
    with open(resultsPath+dataSet+'/leq'+str(4)+'/'+'RF_'+str(10)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_10_leq4.append(rowStr[1])
                
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_10_t'+str(line_count)+'_leq4'
                line_count+=1
    csv_file.close()
    
    with open(resultsPath+dataSet+'/leq'+str(5)+'/'+'RF_'+str(10)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_10_leq5.append(rowStr[1])
                
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_10_t'+str(line_count)+'_leq5'
                line_count+=1
    csv_file.close()
    
    with open(resultsPath+dataSet+'/leq'+str(6)+'/'+'RF_'+str(10)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_10_leq6.append(rowStr[1])
                
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_10_t'+str(line_count)+'_leq6'
                line_count+=1
    csv_file.close()
    
    with open(resultsPath+dataSet+'/leq'+str(7)+'/'+'RF_'+str(10)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_10_leq7.append(rowStr[1])
                
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_10_t'+str(line_count)+'_leq7'
                line_count+=1
    csv_file.close()
    
    
    f= open(resultsPath+dataSet+'/RF_all_leq'+'_'+scoring_function+'.csv',"w")
    f.write('Frequency'+','+'DSF_RF_leq2'+','+'DSF_RF_leq3'+','+'DSF_RF_leq4'+','+'DSF_RF_leq5'+','+
                    'DSF_RF_leq6'+','+'DSF_RF_leq7'+','+'Normal Features'+','+'DT Classifier_10'+','+'RF Classifier_10'+','+'DT Classifier_10'+','+'RF Classifier_10'+
            '\n')
    for i in range(24):
            f.write('t'+str(i+2)+','+res_list_dsf_rf_10_leq2[i]+','+res_list_dsf_rf_10_leq3[i]+','+res_list_dsf_rf_10_leq4[i]+','+res_list_dsf_rf_10_leq5[i]+','+
                    res_list_dsf_rf_10_leq6[i]+','+res_list_dsf_rf_10_leq7[i]+','+res_list_normal[i]+','+res_list_dt_10[i]+','+res_list_rf_10[i]+
                    '\n')
    f.close()
    
    res_list_dt = res_list_dt_10
    res_list_rf = res_list_rf_10
    #DT
    '''if (float(res_list_dt_5[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_5[1])
        best_dt='DT_5'
        res_list_dt = res_list_dt_5
    if (float(res_list_dt_10[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_10[1])
        best_dt='DT_10'
        res_list_dt = res_list_dt_10
    if (float(res_list_dt_15[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_15[1])
        best_dt='DT_15'
        res_list_dt = res_list_dt_15
    if (float(res_list_dt_20[1]) > best_value_dt):
        best_value_dt=float(res_list_dt_20[1])
        best_dt='DT_20'
        res_list_dt = res_list_dt_20
    #RF    
    if (float(res_list_rf_5[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_5[1])
        best_rf='RF_5'
        res_list_rf = res_list_rf_5
    if (float(res_list_rf_10[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_10[1])
        best_rf='RF_10'
        res_list_rf = res_list_rf_10
    if (float(res_list_rf_15[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_15[1])
        best_rf='RF_15'
        res_list_rf = res_list_rf_15
    if (float(res_list_rf_20[1]) > best_value_rf):
        best_value_rf=float(res_list_rf_20[1])
        best_rf='RF_20'
        res_list_rf = res_list_rf_20'''
# Out:
# "if (float(res_list_dt_5[1]) > best_value_dt):\n    best_value_dt=float(res_list_dt_5[1])\n    best_dt='DT_5'\n    res_list_dt = res_list_dt_5\nif (float(res_list_dt_10[1]) > best_value_dt):\n    best_value_dt=float(res_list_dt_10[1])\n    best_dt='DT_10'\n    res_list_dt = res_list_dt_10\nif (float(res_list_dt_15[1]) > best_value_dt):\n    best_value_dt=float(res_list_dt_15[1])\n    best_dt='DT_15'\n    res_list_dt = res_list_dt_15\nif (float(res_list_dt_20[1]) > best_value_dt):\n    best_value_dt=float(res_list_dt_20[1])\n    best_dt='DT_20'\n    res_list_dt = res_list_dt_20\n#RF    \nif (float(res_list_rf_5[1]) > best_value_rf):\n    best_value_rf=float(res_list_rf_5[1])\n    best_rf='RF_5'\n    res_list_rf = res_list_rf_5\nif (float(res_list_rf_10[1]) > best_value_rf):\n    best_value_rf=float(res_list_rf_10[1])\n    best_rf='RF_10'\n    res_list_rf = res_list_rf_10\nif (float(res_list_rf_15[1]) > best_value_rf):\n    best_value_rf=float(res_list_rf_15[1])\n    best_rf='RF_15'\n 
# ...

# %%
#Classification results leq
x_axis=np.arange(2,26,1)
dsf_rf_10_leq2 = np.array(res_list_dsf_rf_10_leq2, dtype=np.float32)
dsf_rf_10_leq3 = np.array(res_list_dsf_rf_10_leq3, dtype=np.float32)
dsf_rf_10_leq4 = np.array(res_list_dsf_rf_10_leq4, dtype=np.float32)
dsf_rf_10_leq5 = np.array(res_list_dsf_rf_10_leq5, dtype=np.float32)
dsf_rf_10_leq6 = np.array(res_list_dsf_rf_10_leq6, dtype=np.float32)
dsf_rf_10_leq7 = np.array(res_list_dsf_rf_10_leq7, dtype=np.float32)

normal = np.array(res_list_normal, dtype=np.float32)
dt = np.array(res_list_dt, dtype=np.float32)
rf = np.array(res_list_rf, dtype=np.float32)

print('Best: '+best +': '+str(round(best_value,6)))
diff = normal[0] - best_value 
print('Difference from normal features: '+str(round(diff,6)))

plt.plot(x_axis,dsf_rf_10_leq2)
plt.plot(x_axis,dsf_rf_10_leq3)
plt.plot(x_axis,dsf_rf_10_leq4)
plt.plot(x_axis,dsf_rf_10_leq5)
plt.plot(x_axis,dsf_rf_10_leq6)
plt.plot(x_axis,dsf_rf_10_leq7)
plt.plot(x_axis,normal)
plt.plot(x_axis,dt)
plt.plot(x_axis,rf)
plt.xlabel('Frequency')
plt.ylabel(scoring_function)

ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.70, box.height])
plt.legend(['DFS_RF_10_leq2', 'DFS_RF_10_leq3', 'DFS_RF_10_leq4', 'DFS_RF_10_leq5', 'DFS_RF_10_leq6',
            'DFS_RF_10_leq7','normal features','DT Classifier','RF Classifier'],bbox_to_anchor=(1.0, 0.7), loc='upper left')
plt.text(27, 0.84, 'Best: '+best +': '+str(round(best_value,6))+'\n'+'Difference from normal \n features: '+str(round(diff,6)))
fig = plt.gcf()
fig.savefig(dataSet+'_'+scoring_function+'_leq.png', dpi=150)
fig.show()
# Out:
# Best: RF_10_t4_leq2: 0.810325
# Difference from normal features: -0.015172
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
    #Classification time 
    res_list_dsf_rf_5=[]
    res_list_dsf_rf_10=[]
    res_list_dsf_rf_15=[]
    res_list_dsf_rf_20=[]
    res_list_normal=[]
    res_list_dt=[]
    res_list_dt_5=[]
    res_list_dt_10=[]
    res_list_dt_15=[]
    res_list_dt_20=[]
    res_list_rf=[]
    res_list_rf_5=[]
    res_list_rf_10=[]
    res_list_rf_15=[]
    res_list_rf_20=[]
    best=''
    best_value=20
    best_dt=''
    best_value_dt=20
    best_rf=''
    best_value_rf=20
    pattern_max_size = 6
    variant = 'NoLeafEdges'
    
  
    with open(resultsPath+dataSet+'/Results_'+variant+'/leq'+str(pattern_max_size)+'/'+'RF_'+str(5)+'_'+scoring_function+'_time.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_5.append(rowStr[1])
                res_list_normal.append(rowStr[2])
                res_list_dt_5.append(rowStr[3])
                res_list_rf_5.append(rowStr[4])
                if (float(rowStr[1]) < best_value):
                    best_value=float(rowStr[1])
                    best='RF_5_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    res_list_rf_10=[]
    with open(resultsPath+dataSet+'/Results_'+variant+'/leq'+str(pattern_max_size)+'/RF_'+str(10)+'_'+scoring_function+'_time.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_10.append(rowStr[1])
                res_list_dt_10.append(rowStr[3])
                res_list_rf_10.append(rowStr[4]) 
                if (float(rowStr[1]) < best_value):
                    best_value=float(rowStr[1])
                    best='RF_10_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    res_list_rf_15=[]
    with open(resultsPath+dataSet+'/Results_'+variant+'/leq'+str(pattern_max_size)+'/RF_'+str(15)+'_'+scoring_function+'_time.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_15.append(rowStr[1])
                res_list_dt_15.append(rowStr[3])
                res_list_rf_15.append(rowStr[4]) 
                if (float(rowStr[1]) < best_value):
                    best_value=float(rowStr[1])
                    best='RF_15_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    res_list_rf_20=[]
    with open(resultsPath+dataSet+'/Results_'+variant+'/leq'+str(pattern_max_size)+'/RF_'+str(20)+'_'+scoring_function+'_time.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_rf_20.append(rowStr[1])
                res_list_dt_20.append(rowStr[3])
                res_list_rf_20.append(rowStr[4]) 
                if (float(rowStr[1]) < best_value):
                    best_value=float(rowStr[1])
                    best='RF_20_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    f= open(resultsPath+dataSet+'/Results_'+variant+'/leq'+str(pattern_max_size)+'/RF_all'+'_'+scoring_function+'_time.csv',"w")
    f.write('Frequency'+','+'DSF_RF_5'+','+'DSF_RF_10'+','+'DSF_RF_15'+','+'DSF_RF_20'+','+
                    ','+'Normal Features'+','+'DT Classifier_5'+','+'RF Classifier_5'+','+'DT Classifier_10'+','+'RF Classifier_10'+
            ','+'DT Classifier_15'+','+'RF Classifier_15'+','+'DT Classifier_20'+','+'RF Classifier_20' +'\n')
    for i in range(24):
            f.write('t'+str(i+2)+','+res_list_dsf_rf_5[i]+','+res_list_dsf_rf_10[i]+','+res_list_dsf_rf_15[i]+','+res_list_dsf_rf_20[i]+','+
                    res_list_normal[i]+','+res_list_dt_5[i]+','+res_list_rf_5[i]+res_list_dt_10[i]+','+res_list_rf_10[i]+
                    res_list_dt_15[i]+','+res_list_rf_15[i]+res_list_dt_20[i]+','+res_list_rf_20[i]+'\n')
    f.close()
    
    #DT
    if (float(res_list_dt_5[1]) < best_value_dt):
        best_value_dt=float(res_list_dt_5[1])
        best_dt='DT_5'
        res_list_dt = res_list_dt_5
    if (float(res_list_dt_10[1]) < best_value_dt):
        best_value_dt=float(res_list_dt_10[1])
        best_dt='DT_10'
        res_list_dt = res_list_dt_10
    if (float(res_list_dt_15[1]) < best_value_dt):
        best_value_dt=float(res_list_dt_15[1])
        best_dt='DT_15'
        res_list_dt = res_list_dt_15
    if (float(res_list_dt_20[1]) < best_value_dt):
        best_value_dt=float(res_list_dt_20[1])
        best_dt='DT_20'
        res_list_dt = res_list_dt_20
    #RF    
    if (float(res_list_rf_5[1]) < best_value_rf):
        best_value_rf=float(res_list_rf_5[1])
        best_rf='RF_5'
        res_list_rf = res_list_rf_5
    if (float(res_list_rf_10[1]) < best_value_rf):
        best_value_rf=float(res_list_rf_10[1])
        best_rf='RF_10'
        res_list_rf = res_list_rf_10
    if (float(res_list_rf_15[1]) < best_value_rf):
        best_value_rf=float(res_list_rf_15[1])
        best_rf='RF_15'
        res_list_rf = res_list_rf_15
    if (float(res_list_rf_20[1]) < best_value_rf):
        best_value_rf=float(res_list_rf_20[1])
        best_rf='RF_20'
        res_list_rf = res_list_rf_20

# %%
#Classification time
x_axis=np.arange(2,26,1)
dsf_rf_5 = np.array(res_list_dsf_rf_5, dtype=np.float32)
dsf_rf_10 = np.array(res_list_dsf_rf_10, dtype=np.float32)
dsf_rf_15 = np.array(res_list_dsf_rf_15, dtype=np.float32)
dsf_rf_20 = np.array(res_list_dsf_rf_20, dtype=np.float32)
normal = np.array(res_list_normal, dtype=np.float32)
dt = np.array(res_list_dt, dtype=np.float32)
rf = np.array(res_list_rf, dtype=np.float32)

print('Best: '+best +': '+str(round(best_value,6)))
diff = normal[0] - best_value 
print('Difference from normal features: '+str(round(diff,6)))

plt.plot(x_axis,dsf_rf_5)
plt.plot(x_axis,dsf_rf_10)
plt.plot(x_axis,dsf_rf_15)
plt.plot(x_axis,dsf_rf_20)
plt.plot(x_axis,normal)
plt.plot(x_axis,dt)
plt.plot(x_axis,rf)
plt.xlabel('Frequency')
plt.ylabel('time (sec)')

ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.70, box.height])
plt.legend(['DFS_RF_5', 'DFS_RF_10', 'DFS_RF_15', 'DFS_RF_20','normal features','DT Classifier','RF Classifier'],bbox_to_anchor=(1.0, 0.5), loc='upper left')
#plt.text(27, 0.8, 'Best: '+best +': '+str(round(best_value,6))+'\n'+'Difference from normal \n features: '+str(round(diff,6)))
fig = plt.gcf()
fig.savefig(dataSet+'_'+variant+'_time_'+scoring_function+'.png', dpi=150)
fig.show()
# Out:
# Best: RF_5_t21: 0.041859
# Difference from normal features: 0.122378
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:25: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:32: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
    # classification with vs no leaf edges
    #Classification
    res_list_dsf_no=[]
    res_list_dsf_with=[]
    depth = 10
   
   
    best=''
    best_value=0
    best_dt=''
    best_value_dt=0
    best_rf=''
    best_value_rf=0
    pattern_max_size = 6
    variant_With = 'WithLeafEdges'
    variant_No = 'NoLeafEdges'
    
  
    with open(resultsPath+dataSet+'/Results_'+variant_With+'/leq'+str(pattern_max_size)+'/'+'RF_'+str(depth)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_with.append(rowStr[1])
                
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_5_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    res_list_rf_10=[]
    with open(resultsPath+dataSet+'/Results_'+variant_No+'/leq'+str(pattern_max_size)+'/RF_'+str(depth)+'_'+scoring_function+'.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_no.append(rowStr[1])
                
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_5_t'+str(line_count)
                line_count+=1
    csv_file.close()

# %%
#Classification
x_axis=np.arange(2,26,1)
dsf_with = np.array(res_list_dsf_with, dtype=np.float32)
dsf_no = np.array(res_list_dsf_no, dtype=np.float32)


print('Best: '+best +': '+str(round(best_value,6)))
diff = normal[0] - best_value 
print('Difference from normal features: '+str(round(diff,6)))

diff_from_rf = best_value - best_value_rf

plt.plot(x_axis,dsf_with)
plt.plot(x_axis,dsf_no)
plt.xlabel('Frequency')
plt.ylabel(scoring_function)

ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.60, box.height])
plt.legend(['DSF_RF_'+str(depth)+'_With', 'DSF_RF_'+str(depth)+'_No'],bbox_to_anchor=(1.0, 0.5), loc='upper left')
#plt.text(27, 0.77, 'Best: '+best +': '+str(round(best_value,6))+'\n\n'+'Difference from normal \n features: '+str(round(diff,6))+'\n\n'+'Best RF: '+best_rf+ ' :'+str(round(best_value_rf,6))+
#        '\n'+'Difference from RF Classifier: \n '+str(round(diff_from_rf,6))+'\n')
fig = plt.gcf()
fig.savefig(dataSet+'_comparison_with_no'+str(depth)+'_'+scoring_function+'.png', dpi=150)
fig.show()

# Notes 10 Dec meeting:

# display which RF depth is the best
# what we gain if the RF classifier is better than the frequent subtrees ?
# when the max depth is 5, we pruned 25 trees of the random forest
# check the computation time, RF is better than the frequent sebtrees.
# define the final goal clearly.
# Out:
# Best: RF_5_t7: 0.834311
# Difference from normal features: -0.039157
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:26: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
    # time
    #classification with vs no leaf edges
    #Classification
    res_list_dsf_no=[]
    res_list_dsf_with=[]
    depth = 5
   
   
    best=''
    best_value=0
    best_dt=''
    best_value_dt=0
    best_rf=''
    best_value_rf=0
    pattern_max_size = 6
    variant_With = 'WithLeafEdges'
    variant_No = 'NoLeafEdges'
    
  
    with open(resultsPath+dataSet+'/Results_'+variant_With+'/leq'+str(pattern_max_size)+'/'+'RF_'+str(depth)+'_'+scoring_function+'_time.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_with.append(rowStr[1])
                
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_5_t'+str(line_count)
                line_count+=1
    csv_file.close()
    
    res_list_rf_10=[]
    with open(resultsPath+dataSet+'/Results_'+variant_No+'/leq'+str(pattern_max_size)+'/RF_'+str(depth)+'_'+scoring_function+'_time.csv') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter='\n')
        line_count = 2
        for row in csv_reader:
            rowStr = str(row).split(',')
            if line_count < 26:
                res_list_dsf_no.append(rowStr[1])
                
                if (float(rowStr[1]) > best_value):
                    best_value=float(rowStr[1])
                    best='RF_5_t'+str(line_count)
                line_count+=1
    csv_file.close()

# %%
#Classification
x_axis=np.arange(2,26,1)
dsf_with = np.array(res_list_dsf_with, dtype=np.float32)
dsf_no = np.array(res_list_dsf_no, dtype=np.float32)


print('Best: '+best +': '+str(round(best_value,6)))
diff = normal[0] - best_value 
print('Difference from normal features: '+str(round(diff,6)))

diff_from_rf = best_value - best_value_rf

plt.plot(x_axis,dsf_with)
plt.plot(x_axis,dsf_no)
plt.xlabel('Frequency')
plt.ylabel('time (sec)')

ax = plt.subplot(111)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.60, box.height])
plt.legend(['DSF_RF_'+str(depth)+'_With', 'DSF_RF_'+str(depth)+'_No'],bbox_to_anchor=(1.0, 0.5), loc='upper left')
#plt.text(27, 0.77, 'Best: '+best +': '+str(round(best_value,6))+'\n\n'+'Difference from normal \n features: '+str(round(diff,6))+'\n\n'+'Best RF: '+best_rf+ ' :'+str(round(best_value_rf,6))+
#        '\n'+'Difference from RF Classifier: \n '+str(round(diff_from_rf,6))+'\n')
fig = plt.gcf()
fig.savefig(dataSet+'time_comparison_with_no'+str(depth)+'_'+scoring_function+'.png', dpi=150)
fig.show()

# Notes 10 Dec meeting:

# display which RF depth is the best
# what we gain if the RF classifier is better than the frequent subtrees ?
# when the max depth is 5, we pruned 25 trees of the random forest
# check the computation time, RF is better than the frequent sebtrees.
# define the final goal clearly.
# Out:
# Best: RF_5_t2: 14.649395
# Difference from normal features: -13.854242
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /home/falkhoury/anaconda3/envs/py3k/lib/python3.7/site-packages/ipykernel_launcher.py:26: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
